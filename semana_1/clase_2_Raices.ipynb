# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %% [markdown]
# # Método de Bisección

# %% [markdown]
# Encontrar las raices de la función:
#
# \begin{equation}
#     f(x) = \sqrt{x} - \cos{x}
# \end{equation}

# %%
#graficamos para encontrar los puntos cercas de la raiz
x = np.linspace(0,1,500)
y = np.sqrt(x)-np.cos(x)
plt.plot(x,y)
plt.xlabel("x",fontsize=18)
plt.ylabel("f(x)",fontsize=18)
plt.show()

# %%
a = 0.6
b = 0.9 


p = (a+b)/2
for i in range(0,100):
    y_p = np.sqrt(p)-np.cos(p)
    if y_p < 0:
        a = p
    if y_p > 0:
        b = p
    p = (a+b)/2

print(y_p)
x = np.linspace(0,1,500)
y = np.sqrt(x)-np.cos(x)
plt.plot(x,y)
plt.xlabel("x",fontsize=18)
plt.ylabel("f(x)",fontsize=18)
plt.plot(p,y_p,'ro',label='$raiz={:.6f}$'.format(p))
plt.legend(loc='upper right', shadow=True, fontsize='x-large')
plt.show()
# Out:
# 0.0

# %% [markdown]
# Encontrar las raices de la función:
#
# \begin{equation}
#     f(x) = x^2 - e^{x}
# \end{equation}

# %%
#graficamos para encontrar los puntos cercas de la raiz
x = np.linspace(-4,2.5,500)
y = np.power(x,2) - np.exp(x) 
plt.plot(x,y)
plt.xlabel("x",fontsize=18)
plt.ylabel("f(x)",fontsize=18)
plt.show()

# %%
a = 2
b = -2

p = (a+b)/2
for i in range(0,100):
    y_p = np.power(p,2) - np.exp(p) 
    if y_p < 0:
        a = p
    if y_p > 0:
        b = p
    p = (a+b)/2

print(y_p)    
x = np.linspace(-4,2.5,500)
y = np.power(x,2) - np.exp(x) 
plt.plot(x,y)
plt.xlabel("x",fontsize=18)
plt.ylabel("f(x)",fontsize=18)
plt.plot(p,y_p,'ro',label='$raiz={:.6f}$'.format(p))
plt.legend(loc='upper right', shadow=True, fontsize='x-large')
plt.show()
# Out:
# 0.0
