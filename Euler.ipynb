# %%
from pylab import*

# %%
def f(y):
    return y
N=10000
a,b=0.,1.
t=linspace(a,b,N)
y=empty(N)
y[0]=1
h=(b-a)/N
for i in range(1,N):
    y[i]=y[i-1]+h*f(y[i-1])
plot(t,y,'.')
plot(t,exp(t))
show()
