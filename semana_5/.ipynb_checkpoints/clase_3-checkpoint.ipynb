# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import pylab as pl 
from scipy.interpolate import interp1d

# %%
def f(t,x,y):
    return 5*x-3*y

# %%
def g(t,x,y):
    return -6*x+2*y

# %%
N=1000
a = 0.
b = 1/4
h = (b-a)/N

t = np.linspace(a,b,N)
x_rk = [0]
y_rk = [1]

for i in range(1,N):
    k1 = h*f(t[i-1],x_rk[i-1],y_rk[i-1])
    l1 = h*g(t[i-1],x_rk[i-1],y_rk[i-1])
    
    k2 = h*f(t[i-1]+0.5*h,x_rk[i-1]+0.5*k1,y_rk[i-1]+0.5*l1)
    l2 = h*g(t[i-1]+0.5*h,x_rk[i-1]+0.5*k1,y_rk[i-1]+0.5*l1)
    
    k3 = h*f(t[i-1]+0.5*h,x_rk[i-1]+0.5*k2,y_rk[i-1]+0.5*l2)
    l3 = h*g(t[i-1]+0.5*h,x_rk[i-1]+0.5*k2,y_rk[i-1]+0.5*l2)
    
    k4 = h*f(t[i-1]+h,x_rk[i-1]+k3,y_rk[i-1]+l3)
    l4 = h*g(t[i-1]+h,x_rk[i-1]+k3,y_rk[i-1]+l3)
    
    x_rk.append(x_rk[i-1]+(k1+2.*k2+2.*k3+k4)/6.)
    y_rk.append(y_rk[i-1]+(l1+2.*l2+2.*l3+l4)/6.)

# %%
x_e = (1/3.)*np.exp(-t) -(1/3.)*np.exp(8*t)
y_e = (2/3.)*np.exp(-t) +(1/3.)*np.exp(8*t)

# %%
plt.figure(figsize=(8,8))
plt.plot(t,x_rk,'yo',label='$x(t)\quad RK$')
plt.plot(t,y_rk,'o', color='salmon',label='$y(t)\quad RK$')
plt.plot(t,x_e,'r--',label='$x(t)\quad exacta$')
plt.plot(t,y_e,'k--',label='$y(t)\quad exacta$')
plt.legend(loc='center right', shadow=True, frameon = False , fontsize='x-large')
