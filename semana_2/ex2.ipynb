# %%
#Interpolación cúbica
def Cubica(xs,ys,datos):
    k=0
    ecu1=[]
    ecu1y=[]
    for i in range(2,datos):
        ecu11=[]
        a=(xs[i-1])**3
        b=(xs[i-1])**2
        c=(xs[i-1])
        d=1
        e=(ys[i-1])
        p=(4*(datos-1))-4
        for i in range(p):
            ecu11.append(0)
        ecu11.insert(k,d)
        ecu11.insert(k,c)
        ecu11.insert(k,b)
        ecu11.insert(k,a)
        ecu1.append(ecu11)
        ecu1y.append(e)
        k=k+4
       
    k=4
    ecu2=[]
    ecu2y=[]
    for i in range(2,datos):
        ecu22=[]
        a=(xs[i-1])**3
        b=(xs[i-1])**2
        c=(xs[i-1])
        d=1
        e(ys[i-1])
        p=(4*(datos-1))-4
        for i in range(p):
            ecu22.append(0)
        ecu22.insert(k,d)
        ecu22.insert(k,c)
        ecu22.insert(k,b)
        ecu22.insert(k,a)
        ecu2.append(ecu11)
        ecu2y.append(e)
        k=k+4
       
    ecu3=[(xs[0])**3,(xs[0])**2,xs[0],1]
    p=(4*(datos-1))-len(ecu3)
    for i in range(p):
        ecu3.append(0)
    ecu3y=ys[0]
   
    a=(xs[datos-1])**3
    b=(xs[datos-1])**2
    c=(xs[datos-1])
    ecu4=[a,b,c,1]
    p=(4*(datos-1))-len(ecu4)
    for i in range(p):
        ecu4.insert(0,0)
    ecu4y=ys[datos-1]
   
    w=4
    u=0
    ecu5=[]
    ecu5y=[]
    for i in range(2,datos):
        ecu55=[]
        p=(4*(datos-1))-6
        for k in range(p):
            ecu55.append(0)
        a=(xs[i-1]**2)*3
        b=(xs[i-1])*2
        c=1
        ecu55.insert(u,c)
        ecu55.insert(u,b)
        ecu55.insert(u,a)
        ecu55.insert(w,-c)
        ecu55.insert(w,-b)
        ecu55.insert(w,-a)
        ecu5.append(ecu55)
        u=u+4
        w=w+4
        ecu5y.append(0)
       
    w=4
    u=0
    ecu6=[]
    ecu6y=[]
    for i in range(2,datos):
        ecu66=[]
        a=(xs[i-1])*6
        b=2
        p=(4*(datos-1))-4
        for k in range(p):
            ecu66.apend(0)
        ecu66.insert(u,b)
        ecu66.insert(u,a)
        ecu66.insert(w,-b)
        ecu66.insert(w,-a)
        ecu6.append(ecu66)
        u=u+4
        w=w+4
        ecu6y.append(0)
       
    a=6*xs[0]
    b=2
    ecu7=[]
    p=(4*(datos-1))-2
    for k in range(p):
        ecu7.append(0)
    ecu7.insert(0,b)
    ecu7.insert(0,a)
    ecu7y=0
   
    a=6*xs[datos-1]
    b=2
    w=4*(datos-1)
    ecu8=[]
    p=(4*(datos-1))-2
    for k in range(p):
        ecu8.append(0)
    ecu8.insert(w,b)
    ecu8.insert(w,a)
    ecu8y=0
   
    matriz=[]
    matrizy=[]
   
    for i in range(len(ecu1)):
        matriz.append(ecu1[i])
        matrizy.append(ecu1y[i])
        matriz.append(ecu2[i])
        matrizy.append(ecu2y[i])
       
    matriz.append(ecu3)
    matriz.append(ecu3y)
   
    matriz.append(ecu4)
    matrizy.append(ecu4y)
   
    for i in range(len(ecu5)):
        matriz.append(ecu5[i])
        matrizy.append(ecu5y[i])
       
    for i in range(len(ecu6)):
        matriz.append(ecu6[i])
        matrizy.append(ecu6y[i])
       
    matriz.append(ecu7)
    matrizy.append(ecu7y)
   
    matriz.append(ecu8)
    matrizy.append(ecu8y)
   
    x=np.linalg.solve(matriz,matrizy)
    print (x)
    for i, x in enumerate(X):
        print ('x%d valor: %f' % (i,x))
        print
    return X
   
datos = input(21)
xs=[0.9,1.3,1.9,2.1,2.6,3.0,3.9,4.4,4.7,5.0,6.0,7.0,8.0,9.2,10.5,11.3,11.6,12.0,12.6,13.0,13.3]
ys=[1.3,1.5,1.85,2.1,2.6,2.7,2.4,2.15,2.05,2.1,2.25,2.3,2.25,1.95,1.4,0.9,0.7,0.6,0.5,0.4,0.25]
for i in range(datos):
    print(x[0])
    xs.append(x)
    ys.append(y)
   
X3=Cubica(xs,ys,datos)

def evaluar(xs,X3,m):
    j=0
    for i in range(0,datos-1):
        a=xs[i]
        b=xs[i+1]
        if xs[i] <= m and m <= xs[i+1]:
            G=(X3[j])*(m**3)+(X3[j+1])*(m**2)+(X3[j+2])*(m)+(X3[j+3])
        j=j+4
    return G

n=50
for i in range(n):
    seg3=evaluar(xs,X3,m)
